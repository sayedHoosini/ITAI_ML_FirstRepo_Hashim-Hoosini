# %%
# Print a welcome message
print("Hello! Welcome to Machine Learning Tools in Colab.")

# Define two numbers and perform basic calculations
a = 10
b = 5

sum_result = a + b
product_result = a * b

# Display the results
print(f"Sum: {a} + {b} = {sum_result}")
print(f"Product: {a} * {b} = {product_result}")
# Out:
# Hello! Welcome to Machine Learning Tools in Colab.
# Sum: 10 + 5 = 15
# Product: 10 * 5 = 50
